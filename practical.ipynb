# %% [markdown]
# <a href="https://colab.research.google.com/github/yuganshnirwan/Basics-of-Python/blob/main/practical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDA using python

# %%
# EDA Using python
## Expet-1
### Python basics
print("Hellow this isw my first python program")
a = "hello"
print(a)
print("hello"); print("i am good "); print("bye bro")
print("hello world!",end= " ")
print("I will print on the same line ")
# Out:
# Hellow this isw my first python program
# hello
# hello
# i am good
# bye bro
# hello world!

# %% [markdown]
# #Print numbers
# a=3
# print(a)
# print(358)

# %%
# Case-sensitive
a =4
A = "Sally"
print(a)
print(A)
# Out:
# 4
# Sally

# %%
#Many values to multiple variables
x,y,z = "orange","banana","watermelon"
print(x)
print(y)
print(z)
# Out:
# orange
# banana
# watermelon

# %%
a = 10
b = 30
print("Subtraction = ",a-b)
print("Multiplication = ",a*b)
# Out:
# Subtraction =  -20
# Multiplication =  300

# %%
#Understanding data types
x = 10
y = 3.14
z = "python"
flag = True

# %%
# calculator
a_str = input("Enter first number:")
b_str = input("enter second number:")

# Convert inputs to integers
a = int(a_str)
b = int(b_str)

print("Concatenation of inputs (as strings) =", a_str + b_str)
print("Sum =", a + b)
print("Subtraction =", a - b)
print("Multiplication =", a * b)
print("Division =", a / b)
# Out:
# Enter first number:3
# enter second number:5
# Concatenation of inputs (as strings) = 35
# Sum = 8
# Subtraction = -2
# Multiplication = 15
# Division = 0.6

# %%
name = input("enter your name : ")
age = input("Enter your age: ")
a_str = input("Enter marks for first subject: ")
b_str = input("Enter marks for second subject: ")
c_str = input("Enter marks for third subject: ")
d_str = input("Enter marks for fourth subject: ")
e_str = input("Enter marks for fifth subject: ")
a = int(a_str)
b = int(b_str)
c = int(c_str)
d = int(d_str)
e = int(e_str)
sum = a+b+c+d+e
average = sum/5
print("average marks is equal to ",average)
# Out:
# enter your name : 5
# Enter your age: 3
# Enter marks for first subject: 2
# Enter marks for second subject: 5
# Enter marks for third subject: 8
# Enter marks for fourth subject: 3
# Enter marks for fifth subject: 9
# average marks is equal to  5.4

# %%
#Area of triangle and rectangle
l_str = input("Enter length of rectangle: ")
b_str = input("Enter breadth of rectangle: ")
l = int(l_str)
b = int(b_str)
area = l*b
print("Area of rectangle is :",area)
# Out:
# Enter length of rectangle: 2
# Enter breadth of rectangle: 5
# Area of rectangle is : 10

# %%
a= tuple(5,4,5)
b = tuple(4,7,8)
c = a**b
print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4055372686.py in <cell line: 0>()
# ----> 1 a= tuple(5,4,5)
#       2 b = tuple(4,7,8)
#       3 c = a**b
#       4 print(c)
#
# TypeError: tuple expected at most 1 argument, got 3

# %%
#Understanding data types
x = 10
y = 3.14
z = "Python"
A = True
C = 3+2j
print(type(x))
print(type(y))
print(type(z))
print(type(A))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
